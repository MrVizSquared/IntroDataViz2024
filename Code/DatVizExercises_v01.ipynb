# %% [markdown]
# ## Data Visualization Exercise

# %%
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sn

# %% [markdown]
# ### 1.1 - Read Scatter Data

# %%
df_ = pd.read_csv("./Exercise_ScatterData.csv")

df_.describe()
# Out:
#         Unnamed: 0            f        2dsth        2dstp        2dsts  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    499.500000   249.750000     0.303290     0.727881     0.473663
# std     288.819436   144.409718     0.181490     0.410357     0.248102
# min       0.000000     0.000000     0.024205     0.036891     0.033407
# 25%     249.750000   124.875000     0.163451     0.413930     0.302744
# 50%     499.500000   249.750000     0.286422     0.694230     0.433542
# 75%     749.250000   374.625000     0.434895     0.974107     0.604539
# max     999.000000   499.500000     0.920838     1.904717     1.448738
#
#               3dst           WT
# count  1000.000000  1000.000000
# mean      0.606029     0.615480
# std       0.357403     0.416621
# min       0.037211    -0.025992
# 25%       0.315723     0.209522
# 50%       0.537289     0.578144
# 75%       0.818264     1.029978
# max       1.636288     1.242692

# %% [markdown]
# ### 1.2 - Initial Plot

# %%
plt.plot(df_["f"],df_["2dsth"],'-')
plt.plot(df_["f"],df_["2dstp"],'-')
plt.plot(df_["f"],df_["2dsts"],'-')
plt.plot(df_["f"],df_["3dst" ],'-')
plt.plot(df_["f"],df_["WT"   ],'-')
plt.show()

# %% [markdown]
# ## 2.1 Read Bar Chart 3D Data

# %%
df_ = pd.read_excel("Exercise_BarChart3D.xlsx",sheet_name="Data")
df_.describe()
# Out:
#               Year      2000m      3000m      4000m      5000m      6000m
# count    11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean   2000.000000   1.754545  10.281818  20.563636  29.163636  30.372727
# std       3.316625   1.862452  11.516581  13.789726   6.986454  19.250096
# min    1995.000000   0.000000   1.000000   1.000000  18.100000  15.000000
# 25%    1997.500000   0.100000   2.600000  10.150000  22.600000  17.200000
# 50%    2000.000000   1.500000   5.300000  20.600000  28.800000  17.200000
# 75%    2002.500000   3.600000  16.400000  26.750000  34.150000  37.900000
# max    2005.000000   4.500000  32.900000  47.400000  40.300000  77.000000

# %%
plt.step(df_["Year"],df_["2000m"])
plt.step(df_["Year"],df_["3000m"])
plt.step(df_["Year"],df_["4000m"])
plt.step(df_["Year"],df_["5000m"])
plt.step(df_["Year"],df_["6000m"])
plt.show()

# %% [markdown]
# ### 3.1. Read in Piechart data

# %%
df_ = pd.read_excel("Exercise_Piechart.xlsx")

df_.describe()
# Out:
#          Time [s]
# count   14.000000
# mean    56.585714
# std     62.990865
# min      8.200000
# 25%     17.750000
# 50%     27.000000
# 75%     76.500000
# max    205.000000

# %%
plt.pie(df_['Time [s]'],labels=df_["Algorithm"])
plt.show()

# %% [markdown]
# ### 4.1 Read Histogram Data

# %%
df_well1 = pd.read_excel("Exercise_Histogram.xlsx",sheet_name="Well3")
df_well1.describe()

# %%
df_well2 = pd.read_excel("Exercise_Histogram.xlsx",sheet_name="Well2")
df_well2.describe()
# Out:
#              Depth         RHOB
# count  2031.000000  2031.000000
# mean   3088.690800     2.234618
# std      89.373992     0.089901
# min    2934.004800     1.756200
# 25%    3011.347800     2.211350
# 50%    3088.690800     2.237500
# 75%    3166.033800     2.268650
# max    3243.376800     2.683700

# %%
df_well3 = pd.read_excel("Exercise_Histogram.xlsx",sheet_name="Well3")
df_well3.describe()

# %%
plt.hist(df_well1['RHOB'])
plt.hist(df_well2['RHOB'])
plt.hist(df_well3['RHOB'])
plt.show()
